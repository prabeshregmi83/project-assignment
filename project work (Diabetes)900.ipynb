# %% [markdown]
# # Diabetes prediction project work

# %% [markdown]
# # Introduction:
# Diabetes is a chronic (long-lasting) health condition that affects how your body turns food into energy. Your body breaks down most of the food you eat into sugar (glucose) and releases it into your bloodstream. When your blood sugar goes up, it signals your pancreas to release insulin.

# %% [markdown]
# # Installing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing or loading data sets.

# %%
df = pd.read_csv('diabetes.csv') #importing or loading data sets.
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Top five rows
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Last five rows
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# Showing information about DataFrame
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
# Review data statistics
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Checking missing values
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Correlation

# %%
# checking number of patients who have diabetes
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# Here, 0 represents the number of patients not having diabetes and 1 represents the number of patients having diabetes.Thus,there are 268 patients who are suffered from it.

# %%
sns.countplot(x = df['Outcome'], label = ['False', 'True'])
plt.legend()
plt.show()

# %%
df.columns.tolist()
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# * Here all the column contains outlier so we should check the relation of Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction and Age with Outcome using median and boxplot.

# %% [markdown]
# # Pregnancies

# %%
sns.boxplot(x = df['Outcome'] , y = df['Pregnancies'])
plt.show()

# %%
df.groupby('Outcome').Pregnancies.median()
# Out:
# Outcome
# 0    2.0
# 1    4.0
# Name: Pregnancies, dtype: float64

# %% [markdown]
# # Glucose

# %%
sns.boxplot(x = df['Outcome'], y=df['Glucose'])
plt.show()

# %%
df.groupby('Outcome').Glucose.median()
# Out:
# Outcome
# 0    107.0
# 1    140.0
# Name: Glucose, dtype: float64

# %% [markdown]
# # BloodPressure

# %%
sns.boxplot(x=df['Outcome'], y= df['BloodPressure'])
plt.show()

# %%
df.groupby('Outcome').BloodPressure.median()
# Out:
# Outcome
# 0    70.0
# 1    74.0
# Name: BloodPressure, dtype: float64

# %% [markdown]
# # SkinThickness

# %%
sns.boxplot(x = df['Outcome'], y = df['SkinThickness'])
plt.show()

# %%
df.groupby('Outcome').SkinThickness.median()
# Out:
# Outcome
# 0    21.0
# 1    27.0
# Name: SkinThickness, dtype: float64

# %% [markdown]
# # Insulin

# %%
sns.boxplot(x = df['Outcome'], y = df['Insulin'])
plt.show()

# %%
df.groupby('Outcome').Insulin.median()
# Out:
# Outcome
# 0    39.0
# 1     0.0
# Name: Insulin, dtype: float64

# %% [markdown]
# # BMI

# %%
sns.boxplot(x = df['Outcome'], y = df['BMI'])
plt.show()

# %%
df.groupby('Outcome').BMI.median()
# Out:
# Outcome
# 0    30.05
# 1    34.25
# Name: BMI, dtype: float64

# %% [markdown]
# # DiabetesPedigreeFunction

# %%
sns.boxplot(x = df['Outcome'], y = df['DiabetesPedigreeFunction'])
plt.show()

# %%
df.groupby('Outcome').DiabetesPedigreeFunction.median()
# Out:
# Outcome
# 0    0.336
# 1    0.449
# Name: DiabetesPedigreeFunction, dtype: float64

# %% [markdown]
# # Age

# %%
sns.boxplot(x = df['Outcome'], y = df['Age'])
plt.show()

# %%
df.groupby('Outcome').Age.median()
# Out:
# Outcome
# 0    27.0
# 1    36.0
# Name: Age, dtype: float64

# %% [markdown]
# # Train Test split

# %%
# Importing libraries
from sklearn.model_selection import train_test_split

# %%
df.head(2) # Using 80% data for training and 20% for test
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
X = df.iloc[ : , : -1]
Y = df.iloc[ : , -1]

# %%
X_train , X_test , Y_train ,Y_test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)

# %%
X_train.shape , X_test.shape
# Out:
# ((614, 8), (154, 8))

# %%
Y_train.shape ,Y_test.shape
# Out:
# ((614,), (154,))

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter = 5000)
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# %%
accuracy = accuracy_score(Y_test, Y_pred)

# %%
recall = recall_score(Y_test, Y_pred)

# %%
precision = precision_score(Y_test , Y_pred)

# %%
f1 = f1_score(Y_test , Y_pred) # f1_score is ML evaluation metric that measures model's accuracy

# %%
print(f'''The accuracy score of the model is: {accuracy} i.e. {accuracy * 100} %\n
The recall score of the model is: {recall} i.e. {recall * 100} %\n
The precision score of the model is: {precision} i.e. {precision * 100} %\n
The f1 score of the model is: {f1} i.e. {f1 * 100} %''')
# Out:
# The accuracy score of the model is: 0.7467532467532467 i.e. 74.67532467532467 %
#
# The recall score of the model is: 0.6727272727272727 i.e. 67.27272727272727 %
#
# The precision score of the model is: 0.6379310344827587 i.e. 63.793103448275865 %
#
# The f1 score of the model is: 0.6548672566371682 i.e. 65.48672566371681 %

# %%
cm = confusion_matrix(Y_test , Y_pred)

# %%
fig = ConfusionMatrixDisplay(cm , display_labels = model.classes_)
fig.plot()
plt.show()

# %% [markdown]
# # Then, we need pickel to store the model anywhere else.

# %%
import pickle
with open('diabetes_predictor.pickle', 'wb') as file:
    pickle.dump(model, file)
